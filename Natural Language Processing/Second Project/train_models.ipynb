# %% [markdown]
# # Train Models
# Notebook with the code needed to train and store models
# to disk. This notebook has to be clean (do not define functions here, do them in
# an external utils.py and import them). The notebook has to be reproducible (if
# you run it twice, the same output has to be displayed and stored to disk).

# %% [markdown]
# ## Import Utils and libraries

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# %ls

#from google.colab import runtime
#runtime.unassign()
# Out:
# Mounted at /content/drive/
# drive/  sample_data/

# %%
# Appends the path to our custom module directory
import sys
sys.path.append('/content/drive/MyDrive/JaimeSanchez_AlejandroVara_BrandonAlfaro_DavidIniguez/')

# %%
#Libraries to access the data and save the models
import os
import pickle

# %%
# !pip install scikit-learn
# !pip install cython
# !pip install nltk
# !pip install datasets
import nltk
nltk.download('stopwords')
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (3.0.10)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 23.1 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.2 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 24.0 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, pyarrow, dill, multiprocess, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 16.1.0 which is incompatible.
# Successfully installed datasets-2.20.0 dill-0.3.8 multiprocess-0.70.16 pyarrow-16.1.0 requests-2.32.3 xxhash-3.4.1
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Set the HOME environment variable to the desired path
os.environ['HOME'] = '/content/drive/MyDrive/JaimeSanchez_AlejandroVara_BrandonAlfaro_DavidIniguez/'

# Now you can use os.environ['HOME'] to access the new value
home_dir = os.environ['HOME']

# %%
#Import all libraries, functions and classes needed from utils
exec(open(os.path.join(home_dir, 'utils/utils.py')).read())

# %%
# Support libraries
import pandas as pd
from sklearn.model_selection import train_test_split

# Skseq modules
from skseq.sequences.id_feature import IDFeatures
from skseq.sequences.extended_feature import ExtendedFeatures
from skseq.sequences.structured_perceptron import StructuredPerceptron

# %%
# All directories used
data_dir = os.path.join(home_dir, 'data')
fitted_models_dir = os.path.join(home_dir, 'fitted_models')

# %% [markdown]
# ### Get Training set

# %%
train = pd.read_csv(os.path.join(data_dir, 'train_data_ner.csv'))

# %%
# Words named as 'None' are being considered NA's, fill them as str('None')
train['words'] = train['words'].fillna('None')
X_train, y_train = prepare_data(train)

# %%
print(f'Words of fourth sentence:  {X_train[3]}'); print(f'Tags for the words of fourth sentence: {y_train[3]}')
# Out:
# Words of fourth sentence:  ['U.N.', 'relief', 'coordinator', 'Jan', 'Egeland', 'said', 'Sunday', ',', 'U.S.', ',', 'Indonesian', 'and', 'Australian', 'military', 'helicopters', 'are', 'ferrying', 'out', 'food', 'and', 'supplies', 'to', 'remote', 'areas', 'of', 'western', 'Aceh', 'province', 'that', 'ground', 'crews', 'can', 'not', 'reach', '.']
# Tags for the words of fourth sentence: ['B-geo', 'O', 'O', 'B-per', 'I-per', 'O', 'B-tim', 'O', 'B-geo', 'O', 'B-gpe', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %% [markdown]
# ### Create Vocabulary

# %%
word_dict, tag_dict, _ = create_vocabulary(X_train, y_train)

# %%
print(f'Word Vocabulary : {word_dict}'); print(f'Tag Vocabulary: {tag_dict}')
# Out:
# Word Vocabulary : {'Thousands': 0, 'of': 1, 'demonstrators': 2, 'have': 3, 'marched': 4, 'through': 5, 'London': 6, 'to': 7, 'protest': 8, 'the': 9, 'war': 10, 'in': 11, 'Iraq': 12, 'and': 13, 'demand': 14, 'withdrawal': 15, 'British': 16, 'troops': 17, 'from': 18, 'that': 19, 'country': 20, '.': 21, 'Helicopter': 22, 'gunships': 23, 'Saturday': 24, 'pounded': 25, 'militant': 26, 'hideouts': 27, 'Orakzai': 28, 'tribal': 29, 'region': 30, ',': 31, 'where': 32, 'many': 33, 'Taliban': 34, 'militants': 35, 'are': 36, 'believed': 37, 'fled': 38, 'avoid': 39, 'an': 40, 'earlier': 41, 'military': 42, 'offensive': 43, 'nearby': 44, 'South': 45, 'Waziristan': 46, 'They': 47, 'left': 48, 'after': 49, 'a': 50, 'tense': 51, 'hour-long': 52, 'standoff': 53, 'with': 54, 'riot': 55, 'police': 56, 'U.N.': 57, 'relief': 58, 'coordinator': 59, 'Jan': 60, 'Egeland': 61, 'said': 62, 'Sunday': 63, 'U.S.': 64, 'Indonesian': 65, 'Australian': 66, 'helicopters': 67, 'ferrying': 68, 'out': 69, 'food': 70, 'supplies': 71, 'remote': 72, 'areas': 73, 'western': 74, 'Aceh': 75, 'province': 76, 'ground': 77, 'crews': 78, 'can': 79, 'not': 80, 'reach': 81, 'Mr.': 82, 'latest': 83, 'figures': 84, 'show': 85, '1.8': 86, 'million': 87, 'people': 88, 'need': 89, 'assistance': 90, '-': 91, 'greatest': 92, 'Indonesia': 93, 'Sri': 94, 'Lanka': 95, 'Maldives': 96, 'India': 97, 'He': 98, 'last': 99, 'week': 100, "'s": 101, 'tsunami': 102, 'massive': 103, 'underwater': 104, 'earthquake': 105, 'triggered': 106, 'it': 107, 'has': 108, 'affected': 109, 'millions': 110, 'Asia': 111, 'Africa': 112, 'Some': 113, '1,27,000': 114, 'known': 115, 'dead': 116, 'Lebanese': 117, 'politicians': 118, 'condemning': 119, 'Friday': 120, 'bomb': 121, 'blast': 122, 'Christian': 123, 'neighborhood': 124, 'Beirut': 125, 'as': 126, 'attempt': 127, 'sow': 128, 'sectarian': 129, 'strife': 130, 'formerly': 131, 'war-torn': 132, 'In': 133, 'string': 134, 'officials': 135, 'voiced': 136, 'their': 137, 'anger': 138, 'while': 139, 'at': 140, 'United': 141, 'Nations': 142, 'summit': 143, 'New': 144, 'York': 145, 'Prime': 146, 'Minister': 147, 'Fouad': 148, 'Siniora': 149, 'resolute': 150, 'preventing': 151, 'such': 152, 'attempts': 153, 'destroying': 154, 'spirit': 155, 'One': 156, 'person': 157, 'was': 158, 'killed': 159, 'more': 160, 'than': 161, '20': 162, 'others': 163, 'injured': 164, 'late': 165, 'which': 166, 'took': 167, 'place': 168, 'on': 169, 'residential': 170, 'street': 171, 'Lebanon': 172, 'suffered': 173, 'series': 174, 'bombings': 175, 'since': 176, 'explosion': 177, 'February': 178, 'former': 179, 'Rafik': 180, 'Hariri': 181, 'other': 182, 'Syria': 183, 'is': 184, 'widely': 185, 'accused': 186, 'involvement': 187, 'his': 188, 'killing': 189, 'comes': 190, 'days': 191, 'before': 192, 'investigator': 193, 'Detlev': 194, 'Mehlis': 195, 'return': 196, 'Damascus': 197, 'interview': 198, 'several': 199, 'Syrian': 200, 'about': 201, 'assassination': 202, 'The': 203, 'global': 204, 'financial': 205, 'crisis': 206, 'Iceland': 207, 'economy': 208, 'shambles': 209, 'Israeli': 210, 'say': 211, 'Ariel': 212, 'Sharon': 213, 'will': 214, 'undergo': 215, 'medical': 216, 'procedure': 217, 'Thursday': 218, 'close': 219, 'tiny': 220, 'hole': 221, 'heart': 222, 'discovered': 223, 'during': 224, 'treatment': 225, 'for': 226, 'minor': 227, 'stroke': 228, 'month': 229, 'Doctors': 230, 'describe': 231, 'birth': 232, 'defect': 233, 'partition': 234, 'between': 235, 'upper': 236, 'chambers': 237, 'cardiac': 238, 'catheterization': 239, 'involves': 240, 'inserting': 241, 'catheter': 242, 'blood': 243, 'vessel': 244, 'into': 245, 'umbrella-like': 246, 'device': 247, 'plug': 248, 'they': 249, 'expect': 250, 'make': 251, 'full': 252, 'recovery': 253, 'designers': 254, 'first': 255, 'private': 256, 'manned': 257, 'rocket': 258, 'burst': 259, 'space': 260, 'received': 261, '$': 262, '10': 263, 'prize': 264, 'created': 265, 'promote': 266, 'tourism': 267, 'SpaceShipOne': 268, 'designer': 269, 'Burt': 270, 'Rutan' ...
# Tag Vocabulary: {'O': 0, 'B-geo': 1, 'B-gpe': 2, 'B-tim': 3, 'B-org': 4, 'I-geo': 5, 'B-per': 6, 'I-per': 7, 'I-org': 8, 'B-art': 9, 'I-art': 10, 'I-tim': 11, 'I-gpe': 12, 'B-nat': 13, 'I-nat': 14, 'B-eve': 15, 'I-eve': 16}

# %% [markdown]
# ### Create Sequence List

# %%
train_seq_path = os.path.join(fitted_models_dir, 'train_seq.pkl')

if os.path.exists(train_seq_path):
    print("Model already exists. Loading the saved model.")
    with open(train_seq_path, 'rb') as f:
        train_seq = pickle.load(f)
else:
  train_seq = create_sequence_list(X_train, y_train, word_dict, tag_dict)

  # Save the model
  with open(train_seq_path, 'wb') as f:
      pickle.dump(train_seq, f)

  print("Model saved to:", train_seq_path)
# Out:
# Model already exists. Loading the saved model.

# %%
print(f"Sequence list of fourth sentence: {train_seq[3]}\n")
print(f"Sequence to words and tags: {train_seq[3].to_words(sequence_list = train_seq)}")
# Out:
# Sequence list of fourth sentence: 57/1 58/0 59/0 60/6 61/7 62/0 63/3 31/0 64/1 31/0 65/2 13/0 66/2 42/0 67/0 36/0 68/0 69/0 70/0 13/0 71/0 7/0 72/0 73/0 1/0 74/0 75/1 76/0 19/0 77/0 78/0 79/0 80/0 81/0 21/0
#
# Sequence to words and tags: U.N./B-geo relief/O coordinator/O Jan/B-per Egeland/I-per said/O Sunday/B-tim ,/O U.S./B-geo ,/O Indonesian/B-gpe and/O Australian/B-gpe military/O helicopters/O are/O ferrying/O out/O food/O and/O supplies/O to/O remote/O areas/O of/O western/O Aceh/B-geo province/O that/O ground/O crews/O can/O not/O reach/O ./O

# %% [markdown]
# ## Train Models

# %% [markdown]
# ### Structured Perceptron with Default Features

# %%
feature_mapper = IDFeatures(train_seq)
feature_mapper.build_features()

# %%
show_feats(feature_mapper, train_seq[3])
# Out:
# Initial features
# [70] init_tag:B-geo
#
#
# Transition features
# [11] prev_tag:B-geo::O
# [3] prev_tag:O::O
# [75] prev_tag:O::B-per
# [77] prev_tag:B-per::I-per
# [79] prev_tag:I-per::O
# [32] prev_tag:O::B-tim
# [34] prev_tag:B-tim::O
# [9] prev_tag:O::B-geo
# [11] prev_tag:B-geo::O
# [21] prev_tag:O::B-gpe
# [23] prev_tag:B-gpe::O
# [21] prev_tag:O::B-gpe
# [23] prev_tag:B-gpe::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [9] prev_tag:O::B-geo
# [11] prev_tag:B-geo::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
# [3] prev_tag:O::O
#
#
# Final features
# [28] final_prev_tag:O
#
#
# Emission features
# [71] id:U.N.::B-geo
# [72] id:relief::O
# [73] id:coordinator::O
# [74] id:Jan::B-per
# [76] id:Egeland::I-per
# [78] id:said::O
# [80] id:Sunday::B-tim
# [40] id:,::O
# [81] id:U.S.::B-geo
# [40] id:,::O
# [82] id:Indonesian::B-gpe
# [17] id:and::O
# [83] id:Australian::B-gpe
# [53] id:military::O
# [84] id:helicopters::O
# [47] id:are::O
# [85] id:ferrying::O
# [86] id:out::O
# [87] id:food::O
# [17] id:and::O
# [88] id:supplies::O
# [10] id:to::O
# [89] id:remote::O
# [90] id:areas::O
# [2] id:of::O
# [91] id:western::O
# [92] id:Aceh::B-geo
# [93] id:province::O
# [25] id:that::O
# [94] id:ground::O
# [95] id:crews::O
# [96] id:can::O
# [97] id:not::O
# [98] id:reach::O
# [27] id:.::O

# %%
sp = StructuredPerceptron(word_dict, tag_dict, feature_mapper)
num_epochs = 15

# %%
# %%time
import time

model_file_path = os.path.join(fitted_models_dir, 'sp')

if os.path.exists(model_file_path):
    print("Model already exists. Loading the saved model.")
    with open(model_file_path, 'rb') as f:
        sp = pickle.load(f)
else:
    # Fit the model
    sp.fit(feature_mapper.dataset, num_epochs)

    # Save the model
    sp.save_model(model_file_path)

    print("Model saved to:", model_file_path)
# Out:
# Epoch: 0 Accuracy: 0.893815
# Epoch: 1 Accuracy: 0.931674
# Epoch: 2 Accuracy: 0.940913
# Epoch: 3 Accuracy: 0.946175
# Epoch: 4 Accuracy: 0.950018
# Epoch: 5 Accuracy: 0.952577
# Epoch: 6 Accuracy: 0.954425
# Epoch: 7 Accuracy: 0.956033
# Epoch: 8 Accuracy: 0.957185
# Epoch: 9 Accuracy: 0.958481
# Epoch: 10 Accuracy: 0.959217
# Epoch: 11 Accuracy: 0.960524
# Epoch: 12 Accuracy: 0.961121
# Epoch: 13 Accuracy: 0.961207
# Epoch: 14 Accuracy: 0.961983
# Model saved to: /content/drive/MyDrive/Segunda Entrega NLP /fitted_models/sp
# CPU times: user 1h 50min 30s, sys: 3min 58s, total: 1h 54min 29s
# Wall time: 1h 53min 27s

# %% [markdown]
# #### Profiling

# %%
import io
import pstats
import cProfile

sp_test = StructuredPerceptron(word_dict, tag_dict, feature_mapper)
num_epochs = 1

pr = cProfile.Profile()
pr.enable()
sp_test.fit(feature_mapper.dataset, num_epochs)
pr.disable()
s = io.StringIO()
sortby = 'cumulative'
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
ps.print_stats()
sys.stdout.write(s.getvalue())
# Out:
# Epoch: 0 Accuracy: 0.893815
#          630456675 function calls in 718.185 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000  718.185  359.093 /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3512(run_code)
#         2    0.000    0.000  718.185  359.093 {built-in method builtins.exec}
#         1    0.000    0.000  718.185  718.185 <ipython-input-106-2df70c8b34e6>:1(<cell line: 10>)
#         1    0.001    0.001  718.185  718.185 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/structured_perceptron.py:25(fit)
#         1    0.296    0.296  718.183  718.183 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/structured_perceptron.py:58(fit_epoch)
#     38366    5.889    0.000  717.888    0.019 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/structured_perceptron.py:95(perceptron_update)
#     38366    0.574    0.000  710.895    0.019 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/sequence_classifier.py:124(viterbi_decode)
#     38366  222.204    0.006  427.954    0.011 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/discriminative_sequence_classifier.py:25(compute_scores)
#     38366  111.000    0.003  281.903    0.007 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/sequence_classification_decoder.py:83(run_viterbi)
# 231708489  166.965    0.000  189.649    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/id_feature.py:113(get_transition_features)
#  13651677   19.848    0.000   99.720    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2692(max)
#  13651677   26.536    0.000   79.871    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:71(_wrapreduction)
#  13651677   19.500    0.000   62.680    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:1140(argmax)
#  13651677   12.104    0.000   43.181    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:53(_wrapfunc)
#  13651677   40.890    0.000   40.890    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#  13651677   27.761    0.000   27.761    0.000 {method 'argmax' of 'numpy.ndarray' objects}
# 231938687   22.761    0.000   22.761    0.000 {built-in method builtins.len}
#  14443743   14.930    0.000   14.930    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/id_feature.py:98(get_emission_features)
#  13651677   10.249    0.000   10.249    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:72(<dictcomp>)
#  13651681    3.316    0.000    3.316    0.000 {built-in method builtins.getattr}
#  13651677    3.054    0.000    3.054    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:1136(_argmax_dispatcher)
#  13651677    2.973    0.000    2.973    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2687(_max_dispatcher)
#    191830    2.329    0.000    2.329    0.000 {built-in method numpy.zeros}
#  13651677    2.196    0.000    2.196    0.000 {method 'items' of 'dict' objects}
#     76732    0.990    0.000    1.204    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/numeric.py:136(ones)
#     38366    0.271    0.000    0.464    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/sequence.py:24(copy_sequence)
#    662472    0.397    0.000    0.397    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/id_feature.py:124(get_initial_features)
#    652320    0.309    0.000    0.309    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/id_feature.py:131(get_final_features)
#     76732    0.248    0.000    0.248    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3218(size)
#     38366    0.160    0.000    0.193    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/sequence.py:10(__init__)
#     76732    0.173    0.000    0.173    0.000 {built-in method numpy.empty}
#     38366    0.119    0.000    0.119    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/log_domain.py:8(logzero)
#     38366    0.055    0.000    0.078    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/sequence_classifier.py:18(get_num_states)
#     76732    0.047    0.000    0.047    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3214(_size_dispatcher)
#     76732    0.041    0.000    0.041    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/multiarray.py:1080(copyto)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py:384(write)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py:195(schedule)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/codeop.py:117(__call__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py:545(send)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3337(_update_code_co_name)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:279(helper)
#         3    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1169(is_alive)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py:321(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:102(__init__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/traitlets/traitlets.py:689(__get__)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:130(__enter__)
#         3    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1102(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py:308(_is_master_process)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/traitlets/traitlets.py:651(get)
#         4    0.000    0.000    0.000    0.000 /usr/lib/python3.10/dis.py:453(findlinestarts)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:139(__exit__)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/IPython/core/compilerop.py:166(extra_flags)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/IPython/core/hooks.py:103(__call__)
#         1    0.000    0.000    0.000    0.000 <ipython-input-106-2df70c8b34e6>:1(<cell line: 11>)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py:91(_event_pipe)
#         1    0.000    0.000    0.000    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/sequence_list.py:47(size)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3449(compare)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/IPython/utils/ipstruct.py:125(__getattr__)
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'code' objects}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:1302(user_global_ns)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         3    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:553(is_set)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/IPython/core/hooks.py:168(pre_run_code_hook)
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {method 'co_lines' of 'code' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# ### Structured Perceptron with Extended Features

# %%
feature_mapper_ext = ExtendedFeatures(train_seq)
feature_mapper_ext.build_features()

# %%
show_feats(feature_mapper_ext, train_seq[3])
# Out:
# Initial features
# [91] init_tag:B-geo
#
#
# Transition features
# [18] prev_tag:B-geo::O
# [8] prev_tag:O::O
# [99] prev_tag:O::B-per
# [104] prev_tag:B-per::I-per
# [106] prev_tag:I-per::O
# [46] prev_tag:O::B-tim
# [48] prev_tag:B-tim::O
# [16] prev_tag:O::B-geo
# [18] prev_tag:B-geo::O
# [31] prev_tag:O::B-gpe
# [33] prev_tag:B-gpe::O
# [31] prev_tag:O::B-gpe
# [33] prev_tag:B-gpe::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [16] prev_tag:O::B-geo
# [18] prev_tag:B-geo::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
# [8] prev_tag:O::O
#
#
# Final features
# [39] final_prev_tag:O
#
#
# Emission features
# [92, 14, 93] id:U.N.::B-geo
# [92, 14, 93] capitalized::B-geo
# [92, 14, 93] all_capitalized::B-geo
# [94, 5, 3] id:relief::O
# [94, 5, 3] lower::O
# [94, 5, 3] alphanum::O
# [95, 5, 3] id:coordinator::O
# [95, 5, 3] lower::O
# [95, 5, 3] alphanum::O
# [96, 97, 98] id:Jan::B-per
# [96, 97, 98] capitalized::B-per
# [96, 97, 98] alphanum::B-per
# [100, 101, 102, 103] id:Egeland::I-per
# [100, 101, 102, 103] capitalized::I-per
# [100, 101, 102, 103] alphanum::I-per
# [100, 101, 102, 103] suffix:land::I-per
# [105, 5, 3] id:said::O
# [105, 5, 3] lower::O
# [105, 5, 3] alphanum::O
# [107, 43, 44, 45] id:Sunday::B-tim
# [107, 43, 44, 45] capitalized::B-tim
# [107, 43, 44, 45] alphanum::B-tim
# [107, 43, 44, 45] suffix:day::B-tim
# [54, 38] id:,::O
# [54, 38] punctuation::O
# [108, 14, 93] id:U.S.::B-geo
# [108, 14, 93] capitalized::B-geo
# [108, 14, 93] all_capitalized::B-geo
# [54, 38] id:,::O
# [54, 38] punctuation::O
# [109, 28, 29] id:Indonesian::B-gpe
# [109, 28, 29] capitalized::B-gpe
# [109, 28, 29] alphanum::B-gpe
# [24, 5, 3, 6] id:and::O
# [24, 5, 3, 6] lower::O
# [24, 5, 3, 6] alphanum::O
# [24, 5, 3, 6] stopword::O
# [110, 28, 29] id:Australian::B-gpe
# [110, 28, 29] capitalized::B-gpe
# [110, 28, 29] alphanum::B-gpe
# [69, 5, 3] id:military::O
# [69, 5, 3] lower::O
# [69, 5, 3] alphanum::O
# [111, 5, 3] id:helicopters::O
# [111, 5, 3] lower::O
# [111, 5, 3] alphanum::O
# [63, 5, 3, 6] id:are::O
# [63, 5, 3, 6] lower::O
# [63, 5, 3, 6] alphanum::O
# [63, 5, 3, 6] stopword::O
# [112, 5, 3] id:ferrying::O
# [112, 5, 3] lower::O
# [112, 5, 3] alphanum::O
# [113, 5, 3, 6, 7] id:out::O
# [113, 5, 3, 6, 7] lower::O
# [113, 5, 3, 6, 7] alphanum::O
# [113, 5, 3, 6, 7] stopword::O
# [113, 5, 3, 6, 7] preposition::O
# [114, 5, 3] id:food::O
# [114, 5, 3] lower::O
# [114, 5, 3] alphanum::O
# [24, 5, 3, 6] id:and::O
# [24, 5, 3, 6] lower::O
# [24, 5, 3, 6] alphanum::O
# [24, 5, 3, 6] stopword::O
# [115, 5, 3] id:supplies::O
# [115, 5, 3] lower::O
# [115, 5, 3] alphanum::O
# [17, 5, 3, 6, 7] id:to::O
# [17, 5, 3, 6, 7] lower::O
# [17, 5, 3, 6, 7] alphanum::O
# [17, 5, 3, 6, 7] stopword::O
# [17, 5, 3, 6, 7] preposition::O
# [116, 5, 3] id:remote::O
# [116, 5, 3] lower::O
# [116, 5, 3] alphanum::O
# [117, 5, 3] id:areas::O
# [117, 5, 3] lower::O
# [117, 5, 3] alphanum::O
# [4, 5, 3, 6, 7] id:of::O
# [4, 5, 3, 6, 7] lower::O
# [4, 5, 3, 6, 7] alphanum::O
# [4, 5, 3, 6, 7] stopword::O
# [4, 5, 3, 6, 7] preposition::O
# [118, 5, 3] id:western::O
# [118, 5, 3] lower::O
# [118, 5, 3] alphanum::O
# [119, 14, 15] id:Aceh::B-geo
# [119, 14, 15] capitalized::B-geo
# [119, 14, 15] alphanum::B-geo
# [120, 5, 3] id:province::O
# [120, 5, 3] lower::O
# [120, 5, 3] alphanum::O
# [35, 5, 3, 6] id:that::O
# [35, 5, 3, 6] lower::O
# [35, 5, 3, 6] alphanum::O
# [35, 5, 3, 6] stopword::O
# [121, 5, 3] id:ground::O
# [121, 5, 3] lower::O
# [121, 5, 3] alphanum::O
# [122, 5, 3] id:crews::O
# [122, 5, 3] lower::O
# [122, 5, 3] alphanum::O
# [123, 5, 3, 6] id:can::O
# [123, 5, 3, 6] lower::O
# [123, 5, 3, 6] alphanum::O
# [123, 5, 3, 6] stopword::O
# [124, 5, 3, 6] id:not::O
# [124, 5, 3, 6] lower::O
# [124, 5, 3, 6] alphanum::O
# [124, 5, 3, 6] stopword::O
# [125, 5, 3] id:reach::O
# [125, 5, 3] lower::O
# [125, 5, 3] alphanum::O
# [37, 38] id:.::O
# [37, 38] punctuation::O

# %%
sp_ext = StructuredPerceptron(word_dict, tag_dict, feature_mapper_ext)
num_epochs = 15

# %%
# %%time
model_file_path = os.path.join(fitted_models_dir, 'sp_ext')

if os.path.exists(model_file_path):
    print("Model already exists. Loading the saved model.")
    with open(model_file_path, 'rb') as f:
        sp_ext = pickle.load(f)
else:
    # Fit the model
    sp_ext.fit(feature_mapper_ext.dataset, num_epochs)

    # Save the model
    sp_ext.save_model(model_file_path)

    print("Model saved to:", model_file_path)
# Out:
# Epoch: 0 Accuracy: 0.930567
# Epoch: 1 Accuracy: 0.944572
# Epoch: 2 Accuracy: 0.948740
# Epoch: 3 Accuracy: 0.951372
# Epoch: 4 Accuracy: 0.953064
# Epoch: 5 Accuracy: 0.954413
# Epoch: 6 Accuracy: 0.955548
# Epoch: 7 Accuracy: 0.956655
# Epoch: 8 Accuracy: 0.957372
# Epoch: 9 Accuracy: 0.958522
# Epoch: 10 Accuracy: 0.958742
# Epoch: 11 Accuracy: 0.959553
# Epoch: 12 Accuracy: 0.960095
# Epoch: 13 Accuracy: 0.960533
# Epoch: 14 Accuracy: 0.961149
# Model saved to: /content/drive/MyDrive/Segunda Entrega NLP /fitted_models/sp_ext
# CPU times: user 1h 54min 23s, sys: 4min 7s, total: 1h 58min 31s
# Wall time: 1h 57min 28s

# %% [markdown]
# Profiling

# %%
sp_test_ext = StructuredPerceptron(word_dict, tag_dict, feature_mapper_ext)
num_epochs = 1

pr = cProfile.Profile()
pr.enable()
sp_test_ext.fit(feature_mapper_ext.dataset, num_epochs)
pr.disable()
s = io.StringIO()
sortby = 'cumulative'
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
ps.print_stats()
sys.stdout.write(s.getvalue())
# Out:
# Epoch: 0 Accuracy: 0.930567
#          630187159 function calls in 695.701 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000  695.700  347.850 /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3512(run_code)
#         2    0.000    0.000  695.700  347.850 {built-in method builtins.exec}
#         1    0.000    0.000  695.700  695.700 <ipython-input-113-8beb0ab62768>:1(<cell line: 6>)
#         1    0.001    0.001  695.700  695.700 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/structured_perceptron.py:25(fit)
#         1    0.288    0.288  695.699  695.699 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/structured_perceptron.py:58(fit_epoch)
#     38366    3.939    0.000  695.411    0.018 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/structured_perceptron.py:95(perceptron_update)
#     38366    0.539    0.000  690.701    0.018 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/sequence_classifier.py:124(viterbi_decode)
#     38366  227.365    0.006  428.997    0.011 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/discriminative_sequence_classifier.py:25(compute_scores)
#     38366  103.819    0.003  260.732    0.007 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/sequence_classification_decoder.py:83(run_viterbi)
# 231604387  163.097    0.000  184.923    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/id_feature.py:113(get_transition_features)
#  13651677   18.683    0.000   93.406    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2692(max)
#  13651677   24.900    0.000   74.723    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:71(_wrapreduction)
#  13651677   18.462    0.000   55.649    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:1140(argmax)
#  13651677   38.029    0.000   38.029    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#  13651677   11.463    0.000   37.187    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:53(_wrapfunc)
#  13651677   22.556    0.000   22.556    0.000 {method 'argmax' of 'numpy.ndarray' objects}
# 231834585   21.898    0.000   21.898    0.000 {built-in method builtins.len}
#  14382063   15.794    0.000   15.794    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/id_feature.py:98(get_emission_features)
#  13651677    9.739    0.000    9.739    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:72(<dictcomp>)
#  13651681    3.168    0.000    3.168    0.000 {built-in method builtins.getattr}
#  13651677    2.843    0.000    2.843    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:1136(_argmax_dispatcher)
#  13651677    2.799    0.000    2.799    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2687(_max_dispatcher)
#  13651677    2.056    0.000    2.056    0.000 {method 'items' of 'dict' objects}
#    191830    1.568    0.000    1.568    0.000 {built-in method numpy.zeros}
#     76732    0.943    0.000    1.146    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/numeric.py:136(ones)
#     38366    0.251    0.000    0.432    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/sequence.py:24(copy_sequence)
#    662860    0.373    0.000    0.373    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/id_feature.py:124(get_initial_features)
#    652300    0.327    0.000    0.327    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/id_feature.py:131(get_final_features)
#     76732    0.232    0.000    0.232    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3218(size)
#     38366    0.150    0.000    0.181    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/sequence.py:10(__init__)
#     76732    0.167    0.000    0.167    0.000 {built-in method numpy.empty}
#     38366    0.116    0.000    0.116    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/log_domain.py:8(logzero)
#     38366    0.056    0.000    0.079    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/sequence_classifier.py:18(get_num_states)
#     76732    0.042    0.000    0.042    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3214(_size_dispatcher)
#     76732    0.036    0.000    0.036    0.000 /usr/local/lib/python3.10/dist-packages/numpy/core/multiarray.py:1080(copyto)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py:384(write)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py:195(schedule)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/codeop.py:117(__call__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py:545(send)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3337(_update_code_co_name)
#         1    0.000    0.000    0.000    0.000 /content/drive/MyDrive/Segunda Entrega NLP /skseq/sequences/sequence_list.py:47(size)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:279(helper)
#         3    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1169(is_alive)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:102(__init__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py:321(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/traitlets/traitlets.py:689(__get__)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:130(__enter__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py:308(_is_master_process)
#         4    0.000    0.000    0.000    0.000 /usr/lib/python3.10/dis.py:453(findlinestarts)
#         3    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1102(_wait_for_tstate_lock)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/IPython/core/compilerop.py:166(extra_flags)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/traitlets/traitlets.py:651(get)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/IPython/core/hooks.py:103(__call__)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:139(__exit__)
#         1    0.000    0.000    0.000    0.000 <ipython-input-113-8beb0ab62768>:1(<cell line: 7>)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py:91(_event_pipe)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3449(compare)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/IPython/utils/ipstruct.py:125(__getattr__)
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'code' objects}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:1302(user_global_ns)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         3    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:553(is_set)
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {method 'co_lines' of 'code' objects}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.10/dist-packages/IPython/core/hooks.py:168(pre_run_code_hook)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}

# %% [markdown]
# ### Transformers

# %%
X_train, X_val, Y_train, Y_val = train_test_split (X_train, y_train, test_size=0.1)
pre_train = preprocess_tuples(X_train)
pre_val = preprocess_tuples (X_val)

# %%
tags = np.unique(train['tags'].values)
index2tag, tag2index = create_dict (tags)

# %%
label_names = list (tag2index.keys())
print (label_names)
# Out:
# ['O', 'B-art', 'I-art', 'B-eve', 'I-eve', 'B-geo', 'I-geo', 'B-gpe', 'I-gpe', 'B-nat', 'I-nat', 'B-org', 'I-org', 'B-per', 'I-per', 'B-tim', 'I-tim']

# %%
Y_train_labels = create_labels (Y_train, tag2index)
Y_val_labels = create_labels (Y_val, tag2index)

# %%
from transformers import DistilBertForTokenClassification, DistilBertTokenizerFast
from datasets import Dataset

model = DistilBertForTokenClassification.from_pretrained('distilbert-base-cased', num_labels=len(label_names))
tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-cased')

train_dataset, train_labels = tokenize_and_align_labels(pre_train, Y_train_labels, tokenizer)
val_dataset, val_labels = tokenize_and_align_labels(pre_val, Y_val_labels, tokenizer)

num_train_epochs = 30
batch_size = 200
learning_rate = 2e-5
weight_decay = 0.0

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

# Set up the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# Define Cross-Entropy Loss
criterion = nn.CrossEntropyLoss()

# Number of epochs with no improvement after which training will be stopped
patience = 2

model = fit_model (model, train_loader, val_loader, num_train_epochs, optimizer, criterion, patience, device = torch.device("cuda" if torch.cuda.is_available() else "cpu"))

filetransformers = os.path.join(fitted_models_dir, './ner_dl_distilbert')
model.save_pretrained(filetransformers)
# Out:
# Some weights of DistilBertForTokenClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/30, Training Loss: 0.48094756375847525
# Epoch 1/30, Validation Loss: 0.16564376056194305
# Epoch 2/30, Training Loss: 0.16047781912577636
# Epoch 2/30, Validation Loss: 0.13377927504479886
# Epoch 3/30, Training Loss: 0.13045718960162533
# Epoch 3/30, Validation Loss: 0.12181219607591628
# Epoch 4/30, Training Loss: 0.11275484150200221
# Epoch 4/30, Validation Loss: 0.11726282201707364
# Epoch 5/30, Training Loss: 0.09858102713189373
# Epoch 5/30, Validation Loss: 0.11893790178000926
# Epoch 6/30, Training Loss: 0.08611774028984108
# Epoch 6/30, Validation Loss: 0.11978691816329956
# Early stopping triggered after epoch 6
