# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("/content/calendar.csv", error_bad_lines=False)
# Out:
# <ipython-input-2-6f3a2dfd533c>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df1 = pd.read_csv("/content/calendar.csv", error_bad_lines=False)

# %%
df1
# Out:
#                  listing_id        date available    price adjusted_price  \
# 0                     18674  2023-09-06         f  $199.00        $199.00
# 1                     18674  2023-09-07         f  $199.00        $199.00
# 2                     18674  2023-09-08         f  $199.00        $199.00
# 3                     18674  2023-09-09         f  $205.00        $205.00
# 4                     18674  2023-09-10         f  $205.00        $205.00
# ...                     ...         ...       ...      ...            ...
# 6601333  973955397991485811  2024-08-31         f  $210.00        $210.00
# 6601334  973955397991485811  2024-09-01         f  $210.00        $210.00
# 6601335  973955397991485811  2024-09-02         f  $210.00        $210.00
# 6601336  973955397991485811  2024-09-03         f  $210.00        $210.00
# 6601337  973955397991485811  2024-09-04         f  $210.00        $210.00
#
#          minimum_nights  maximum_nights
# ...

# %%
df1.nunique()
# Out:
# listing_id        18086
# date                365
# available             2
# price              2305
# adjusted_price     2211
# minimum_nights      104
# maximum_nights      374
# dtype: int64

# %%
df = pd.read_csv('/content/listings.csv')

# %%
df.nunique()
# Out:
# id                                18086
# name                               6237
# host_id                            6969
# host_name                          3363
# neighbourhood_group                  10
# neighbourhood                        70
# latitude                           8878
# longitude                          9741
# room_type                             4
# price                               698
# minimum_nights                       86
# number_of_reviews                   532
# last_review                        1658
# reviews_per_month                   782
# calculated_host_listings_count       66
# availability_365                    366
# number_of_reviews_ltm               179
# license                            5635
# dtype: int64

# %%
df.head(2)
# Out:
#       id                                               name  host_id  \
# 0  18674  Rental unit in Barcelona · ★4.30 · 3 bedrooms ...    71615
# 1  23197  Rental unit in Sant Adria de Besos · ★4.77 · 3...    90417
#
#           host_name neighbourhood_group          neighbourhood   latitude  \
# 0  Mireia And Maria            Eixample     la Sagrada Família  41.405560
# 1    Etain (Marnie)          Sant Martí  el Besòs i el Maresme  41.412432
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0    2.17262  Entire home/apt    202               1                 38
# 1    2.21975  Entire home/apt    255               3                 73
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2023-06-26               0.30                              30
# 1  2023-08-15               0.48                               2
#
#    availability_365  number_of_reviews_ltm      license
# 0                34                      8  HUTB-002062
# ...

# %%
aux = df[['id','neighbourhood_group','neighbourhood','room_type']]

# %%
df_merge = pd.merge(aux, df1, left_on='id', right_on='listing_id')

# %%
df_merge.head()
# Out:
#       id neighbourhood_group       neighbourhood        room_type  listing_id  \
# 0  18674            Eixample  la Sagrada Família  Entire home/apt       18674
# 1  18674            Eixample  la Sagrada Família  Entire home/apt       18674
# 2  18674            Eixample  la Sagrada Família  Entire home/apt       18674
# 3  18674            Eixample  la Sagrada Família  Entire home/apt       18674
# 4  18674            Eixample  la Sagrada Família  Entire home/apt       18674
#
#          date available    price adjusted_price  minimum_nights  \
# 0  2023-09-06         f  $199.00        $199.00             3.0
# 1  2023-09-07         f  $199.00        $199.00             3.0
# 2  2023-09-08         f  $199.00        $199.00             3.0
# 3  2023-09-09         f  $205.00        $205.00             2.0
# 4  2023-09-10         f  $205.00        $205.00             2.0
#
#    maximum_nights
# 0          1125.0
# 1          1125.0
# 2          1125.0
# 3          1125.0
# ...

# %%
df_merge.drop('id', axis=1)
# Out:
#         neighbourhood_group       neighbourhood        room_type  \
# 0                  Eixample  la Sagrada Família  Entire home/apt
# 1                  Eixample  la Sagrada Família  Entire home/apt
# 2                  Eixample  la Sagrada Família  Entire home/apt
# 3                  Eixample  la Sagrada Família  Entire home/apt
# 4                  Eixample  la Sagrada Família  Entire home/apt
# ...                     ...                 ...              ...
# 6601333              Gràcia   la Vila de Gràcia     Private room
# 6601334              Gràcia   la Vila de Gràcia     Private room
# 6601335              Gràcia   la Vila de Gràcia     Private room
# 6601336              Gràcia   la Vila de Gràcia     Private room
# 6601337              Gràcia   la Vila de Gràcia     Private room
#
#                  listing_id        date available    price adjusted_price  \
# 0                     18674  2023-09-06         f  $199.00        $199.00
# ...

# %%
time = df_merge

# %%
time = time.drop('id', axis = 1)

# %%
time
# Out:
#         neighbourhood_group       neighbourhood        room_type  \
# 0                  Eixample  la Sagrada Família  Entire home/apt
# 1                  Eixample  la Sagrada Família  Entire home/apt
# 2                  Eixample  la Sagrada Família  Entire home/apt
# 3                  Eixample  la Sagrada Família  Entire home/apt
# 4                  Eixample  la Sagrada Família  Entire home/apt
# ...                     ...                 ...              ...
# 6601333              Gràcia   la Vila de Gràcia     Private room
# 6601334              Gràcia   la Vila de Gràcia     Private room
# 6601335              Gràcia   la Vila de Gràcia     Private room
# 6601336              Gràcia   la Vila de Gràcia     Private room
# 6601337              Gràcia   la Vila de Gràcia     Private room
#
#                  listing_id        date available    price adjusted_price  \
# 0                     18674  2023-09-06         f  $199.00        $199.00
# ...

# %%
time['time']= time['date']

# %%
time[['year', 'month', 'day']] = time['date'].str.split('-', expand=True)
time[['year', 'month', 'day']] = time[['year', 'month', 'day']].astype(int)

time.head()
# Out:
#   neighbourhood_group       neighbourhood        room_type  listing_id  \
# 0            Eixample  la Sagrada Família  Entire home/apt       18674
# 1            Eixample  la Sagrada Família  Entire home/apt       18674
# 2            Eixample  la Sagrada Família  Entire home/apt       18674
# 3            Eixample  la Sagrada Família  Entire home/apt       18674
# 4            Eixample  la Sagrada Família  Entire home/apt       18674
#
#          date available    price adjusted_price  minimum_nights  \
# 0  2023-09-06         f  $199.00        $199.00             3.0
# 1  2023-09-07         f  $199.00        $199.00             3.0
# 2  2023-09-08         f  $199.00        $199.00             3.0
# 3  2023-09-09         f  $205.00        $205.00             2.0
# 4  2023-09-10         f  $205.00        $205.00             2.0
#
#    maximum_nights        time  year  month  day
# 0          1125.0  2023-09-06  2023      9    6
# 1          1125.0  2023-09-07  2023      9    7
# ...

# %% [markdown]
# Delete the $ character and delete decimal numbers

# %%
time['adjusted_price'] = time['adjusted_price'].str[1:]
time['price'] = time['price'].str[1:]
time['adjusted_price'] = time['adjusted_price'].astype(str).str.split('.').str.get(0)
time['price'] = time['price'].astype(str).str.split('.').str.get(0)

# %%
time
# Out:
#         neighbourhood_group       neighbourhood        room_type  \
# 0                  Eixample  la Sagrada Família  Entire home/apt
# 1                  Eixample  la Sagrada Família  Entire home/apt
# 2                  Eixample  la Sagrada Família  Entire home/apt
# 3                  Eixample  la Sagrada Família  Entire home/apt
# 4                  Eixample  la Sagrada Família  Entire home/apt
# ...                     ...                 ...              ...
# 6601333              Gràcia   la Vila de Gràcia     Private room
# 6601334              Gràcia   la Vila de Gràcia     Private room
# 6601335              Gràcia   la Vila de Gràcia     Private room
# 6601336              Gràcia   la Vila de Gràcia     Private room
# 6601337              Gràcia   la Vila de Gràcia     Private room
#
#                  listing_id        date available price adjusted_price  \
# 0                     18674  2023-09-06         f   199            199
# ...

# %%
#We delete some columns that are not going to be used
time = time.drop('minimum_nights', axis = 1)
time = time.drop('maximum_nights', axis = 1)

# %%
time = time.drop('adjusted_price', axis = 1)

# %%
#time = time.drop(['neighbourhood_group',	'neighbourhood'], axis = 1)

# %%
time = time.drop('date', axis = 1)

# %%
time
# Out:
#         neighbourhood_group       neighbourhood        room_type  \
# 0                  Eixample  la Sagrada Família  Entire home/apt
# 1                  Eixample  la Sagrada Família  Entire home/apt
# 2                  Eixample  la Sagrada Família  Entire home/apt
# 3                  Eixample  la Sagrada Família  Entire home/apt
# 4                  Eixample  la Sagrada Família  Entire home/apt
# ...                     ...                 ...              ...
# 6601333              Gràcia   la Vila de Gràcia     Private room
# 6601334              Gràcia   la Vila de Gràcia     Private room
# 6601335              Gràcia   la Vila de Gràcia     Private room
# 6601336              Gràcia   la Vila de Gràcia     Private room
# 6601337              Gràcia   la Vila de Gràcia     Private room
#
#                  listing_id available price        time  year  month  day
# 0                     18674         f   199  2023-09-06  2023      9    6
# ...

# %%
time.to_csv('time_extended.csv', index=False)
